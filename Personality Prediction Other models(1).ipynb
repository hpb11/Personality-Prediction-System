# %%
from sklearn.model_selection import GridSearchCV
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn import svm, datasets, metrics, neighbors
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import math
from sklearn.ensemble import RandomForestRegressor

# %%
df_train = pd.read_csv('Train.csv')
train_length = len(df_train)
df_test = pd.read_csv("Test.csv")
df_test
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0    Female   20         7            9                  9              5
# 1      Male   17         5            4                  5              2
# 2    Female   25         5            5                  7              2
# 3    Female   18         6            2                  7              4
# 4    Female   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 310  Female   19         6            5                  6              4
# 311    Male   18         2            5                  8              3
# 312    Male   18         7            5                  6              2
# 313    Male   23         6            7                  5              4
# 314  Female   18         5            7                  3              5
#
#      extraversion Personality (class label)
# 0               5                dependable
# 1               4                   serious
# 2               4                   serious
# 3               7                   serious
# 4               3               responsible
# ..            ...                       ...
# 310             3               extraverted
# 311             7                dependable
# 312             7                   serious
# 313             3               extraverted
# 314             6               extraverted
#
# [315 rows x 8 columns]

# %%
test_length = len(df_test)
df_train.rename(columns = {'Personality (Class label)':'Personality'}, inplace = True) 
df_test.rename(columns = {'Personality (class label)':'Personality'}, inplace = True)
#inpace = True indicates that the dataframe is updated but it will not return anything
# df.rename(columns = {'Personality (Class label)':'Personality'}, inplace = False)
df_train
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0      Male   17         7            4                  7              3
# 1      Male   19         4            5                  4              6
# 2    Female   18         7            6                  4              5
# 3    Female   22         5            6                  7              4
# 4    Female   19         7            4                  6              5
# ..      ...  ...       ...          ...                ...            ...
# 704  Female   20         4            5                  6              6
# 705    Male   18         6            3                  1              5
# 706    Male   22         5            2                  3              6
# 707    Male   19         5            6                  5              7
# 708  Female   18         5            5                  7              6
#
#      extraversion  Personality
# 0               2  extraverted
# 1               6      serious
# 2               5   dependable
# 3               3  extraverted
# 4               4       lively
# ..            ...          ...
# 704             1  responsible
# 705             5   dependable
# 706             1      serious
# 707             5  extraverted
# 708             5  extraverted
#
# [709 rows x 8 columns]

# %%
df = pd.concat([df_train,df_test])
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0      Male   17         7            4                  7              3
# 1      Male   19         4            5                  4              6
# 2    Female   18         7            6                  4              5
# 3    Female   22         5            6                  7              4
# 4    Female   19         7            4                  6              5
# ..      ...  ...       ...          ...                ...            ...
# 310  Female   19         6            5                  6              4
# 311    Male   18         2            5                  8              3
# 312    Male   18         7            5                  6              2
# 313    Male   23         6            7                  5              4
# 314  Female   18         5            7                  3              5
#
#      extraversion  Personality
# 0               2  extraverted
# 1               6      serious
# 2               5   dependable
# 3               3  extraverted
# 4               4       lively
# ..            ...          ...
# 310             3  extraverted
# 311             7   dependable
# 312             7      serious
# 313             3  extraverted
# 314             6  extraverted
#
# [1024 rows x 8 columns]

# %%
label = LabelEncoder()
df['Gender'] = label.fit_transform(df['Gender'])
df.rename(columns = {'Personality (Class label)':'Personality'}, inplace = True)

# %%
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0         2   17         7            4                  7              3
# 1         2   19         4            5                  4              6
# 2         1   18         7            6                  4              5
# 3         1   22         5            6                  7              4
# 4         1   19         7            4                  6              5
# ..      ...  ...       ...          ...                ...            ...
# 310       1   19         6            5                  6              4
# 311       2   18         2            5                  8              3
# 312       2   18         7            5                  6              2
# 313       2   23         6            7                  5              4
# 314       1   18         5            7                  3              5
#
#      extraversion  Personality
# 0               2  extraverted
# 1               6      serious
# 2               5   dependable
# 3               3  extraverted
# 4               4       lively
# ..            ...          ...
# 310             3  extraverted
# 311             7   dependable
# 312             7      serious
# 313             3  extraverted
# 314             6  extraverted
#
# [1024 rows x 8 columns]

# %%
scaler = StandardScaler()
input_columns = ['Gender', 'Age', 'openness', 'neuroticism','conscientiousness', 'agreeableness','extraversion']
output_columns = ['Personality']
df[input_columns] = scaler.fit_transform(df[input_columns])

# %%
df
# Out:
#        Gender       Age  openness  neuroticism  conscientiousness  \
# 0    1.048042 -1.118659  1.332469    -0.367643           1.332579
# 1    1.048042 -0.335674 -0.634539     0.217841          -0.402032
# 2   -0.946744 -0.727166  1.332469     0.803325          -0.402032
# 3   -0.946744  0.838803  0.021130     0.803325           1.332579
# 4   -0.946744 -0.335674  1.332469    -0.367643           0.754375
# ..        ...       ...       ...          ...                ...
# 310 -0.946744 -0.335674  0.676799     0.217841           0.754375
# 311  1.048042 -0.727166 -1.945878     0.217841           1.910783
# 312  1.048042 -0.727166  1.332469     0.217841           0.754375
# 313  1.048042  1.230295  0.676799     1.388809           0.176171
# 314 -0.946744 -0.727166  0.021130     1.388809          -0.980236
#
#      agreeableness  extraversion  Personality
# 0        -1.105651     -1.652627  extraverted
# 1         0.703917      0.921198      serious
# 2         0.100728      0.277742   dependable
# 3        -0.502461     -1.009171  extraverted
# 4         0.100728     -0.365714       lively
# ..             ...           ...          ...
# 310      -0.502461     -1.009171  extraverted
# 311      -1.105651      1.564654   dependable
# 312      -1.708840      1.564654      serious
# 313      -0.502461     -1.009171  extraverted
# 314       0.100728      0.921198  extraverted
#
# [1024 rows x 8 columns]

# %%
df_train = df[:train_length]
df_test = df[train_length:]
X = np.array(df_train[input_columns])
Y = np.array(df_train[output_columns])
X_test = np.array(df_test[input_columns])
Y_test = np.array(df_test[output_columns])

# %% [markdown]
# # K Neighbour Classification

# %%
clf = neighbors.KNeighborsClassifier()
param_grid = [{'n_neighbors': [2,5,10,11,45,50,100,155,23,122,150,300,25,44], 'weights':['uniform','distance']}]

# %%
clf_gs = GridSearchCV(clf, param_grid, cv = 100)
clf_gs.fit(X,Y)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(cv=100, estimator=KNeighborsClassifier(),
#              param_grid=[{'n_neighbors': [2, 5, 10, 11, 45, 50, 100, 155, 23,
#                                           122, 150, 300, 25, 44],
#                           'weights': ['uniform', 'distance']}])

# %%
Predicted_class = clf_gs.predict(X_test)
print(Predicted_class)
# Out:
# ['serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'extraverted' 'serious'
#  'serious' 'serious' 'lively' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'lively' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'lively' 'extraverted'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'dependable'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'lively' 'serious' 'serious' 'serious' 'serious' 'extraverted'
#  'serious' 'lively' 'serious' 'serious' 'serious' 'lively' 'serious'
#  'lively' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'extraverted' 'lively' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'extraverted' 'serious' 'serious' 'serious'
#  'serious' 'lively' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'dependable' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'lively' 'serious' 'serious' 'serious' 'serious' 'serious' 'dependable'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'responsible'
#  'extraverted' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'lively'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'extraverted'
#  'serious' 'serious' 'serious' 'serious' 'responsible' 'lively' 'serious'
#  'dependable' 'serious' 'serious' 'serious' 'lively' 'serious' 'serious'
#  'lively' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'extraverted' 'extraverted' 'serious' 'extraverted' 'serious'
#  'serious' 'serious' 'dependable' 'serious' 'serious' 'serious' 'serious'
#  'dependable' 'serious' 'serious' 'dependable' 'serious' 'serious'
#  'serious' 'serious' 'extraverted' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'extraverted' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'extraverted' 'serious' 'serious' 'serious'
#  'extraverted' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'lively' 'serious' 'lively' 'serious' 'lively' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'extraverted' 'serious' 'lively' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'responsible'
#  'dependable' 'serious' 'serious' 'serious' 'lively' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'lively' 'extraverted' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious' 'serious' 'serious' 'serious'
#  'serious' 'serious' 'serious' 'serious']

# %%
print("Accuracy: ",metrics.accuracy_score(Y_test, Predicted_class)*100)
print("Confusion Matrix: ")
print(metrics.confusion_matrix(Y_test, Predicted_class))
print("Classification Report: ")
print(metrics.classification_report(Y_test,Predicted_class))
# Out:
# Accuracy:  55.23809523809524
# Confusion Matrix:
# [[  4   0   1   0  16]
#  [  4  13   3   0  57]
#  [  0   0   7   1  16]
#  [  0   3   4   2  31]
#  [  0   0   5   0 148]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   dependable       0.50      0.19      0.28        21
#  extraverted       0.81      0.17      0.28        77
#       lively       0.35      0.29      0.32        24
#  responsible       0.67      0.05      0.09        40
#      serious       0.55      0.97      0.70       153
#
#     accuracy                           0.55       315
#    macro avg       0.58      0.33      0.33       315
# weighted avg       0.61      0.55      0.46       315

# %% [markdown]
# # Gaussian Naive Bayes

# %%
clf = GaussianNB()
clf.fit(X,Y)
Predicted_class = clf.predict(X_test)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
Predicted_class
# Out:
# array(['serious', 'dependable', 'extraverted', 'lively', 'dependable',
#        'serious', 'serious', 'extraverted', 'serious', 'serious',
#        'serious', 'serious', 'lively', 'serious', 'serious',
#        'extraverted', 'serious', 'serious', 'serious', 'lively',
#        'extraverted', 'extraverted', 'serious', 'dependable', 'serious',
#        'serious', 'serious', 'extraverted', 'extraverted', 'responsible',
#        'lively', 'extraverted', 'extraverted', 'extraverted', 'serious',
#        'serious', 'serious', 'serious', 'extraverted', 'dependable',
#        'lively', 'serious', 'dependable', 'dependable', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'extraverted',
#        'extraverted', 'dependable', 'lively', 'serious', 'extraverted',
#        'dependable', 'extraverted', 'dependable', 'serious', 'serious',
#        'extraverted', 'extraverted', 'extraverted', 'dependable',
#        'dependable', 'dependable', 'dependable', 'serious', 'dependable',
#        'serious', 'serious', 'serious', 'extraverted', 'serious',
#        'extraverted', 'responsible', 'serious', 'serious', 'lively',
#        'serious', 'serious', 'serious', 'serious', 'serious',
#        'extraverted', 'dependable', 'serious', 'serious', 'serious',
#        'serious', 'lively', 'serious', 'lively', 'serious', 'dependable',
#        'serious', 'serious', 'serious', 'extraverted', 'serious',
#        'serious', 'extraverted', 'extraverted', 'extraverted', 'lively',
#        'serious', 'extraverted', 'serious', 'serious', 'serious',
#        'serious', 'serious', 'dependable', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'serious', 'serious',
#        'extraverted', 'lively', 'extraverted', 'serious', 'dependable',
#        'lively', 'serious', 'serious', 'serious', 'responsible',
#        'serious', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'serious', 'dependable', 'extraverted', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'serious',
#        'extraverted', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'dependable', 'serious', 'extraverted', 'serious',
#        'serious', 'serious', 'extraverted', 'serious', 'extraverted',
#        'responsible', 'extraverted', 'serious', 'serious', 'serious',
#        'dependable', 'serious', 'serious', 'extraverted', 'serious',
#        'extraverted', 'extraverted', 'extraverted', 'responsible',
#        'dependable', 'serious', 'serious', 'serious', 'serious',
#        'serious', 'serious', 'responsible', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'lively', 'serious',
#        'extraverted', 'serious', 'serious', 'extraverted', 'serious',
#        'lively', 'serious', 'serious', 'extraverted', 'serious',
#        'responsible', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'serious', 'serious',
#        'extraverted', 'dependable', 'serious', 'serious', 'extraverted',
#        'extraverted', 'lively', 'serious', 'extraverted', 'dependable',
#        'serious', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'serious', 'extraverted', 'dependable', 'dependable', 'serious',
#        'serious', 'serious', 'extraverted', 'serious', 'extraverted',
#        'extraverted', 'serious', 'dependable', 'extraverted', 'serious',
#        'serious', 'serious', 'extraverted', 'extraverted', 'extraverted',
#        'dependable', 'extraverted', 'serious', 'serious', 'serious',
#        'extraverted', 'dependable', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'lively', 'extraverted', 'responsible',
#        'serious', 'serious', 'extraverted', 'dependable', 'serious',
#        'serious', 'lively', 'serious', 'serious', 'dependable',
#        'dependable', 'extraverted', 'serious', 'lively', 'serious',
#        'extraverted', 'dependable', 'serious', 'extraverted', 'serious',
#        'serious', 'responsible', 'serious', 'serious', 'dependable',
#        'dependable', 'extraverted', 'serious', 'serious', 'lively',
#        'serious', 'extraverted', 'extraverted', 'serious', 'serious',
#        'extraverted', 'extraverted', 'serious', 'serious', 'extraverted',
#        'dependable', 'dependable', 'serious', 'serious', 'extraverted',
#        'lively', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'lively', 'serious', 'dependable', 'extraverted', 'extraverted'],
#       dtype='<U11')

# %%
print("Accuracy: ",metrics.accuracy_score(Y_test, Predicted_class)*100)
print("Confusion Matrix: ")
print(metrics.confusion_matrix(Y_test, Predicted_class))
print("Classification Report: ")
print(metrics.classification_report(Y_test,Predicted_class))
# Out:
# Accuracy:  48.888888888888886
# Confusion Matrix:
# [[  2   4   0   0  15]
#  [  8  39   4   0  26]
#  [  2   5   5   2  10]
#  [  7   7   4   7  15]
#  [ 19  24   8   1 101]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   dependable       0.05      0.10      0.07        21
#  extraverted       0.49      0.51      0.50        77
#       lively       0.24      0.21      0.22        24
#  responsible       0.70      0.17      0.28        40
#      serious       0.60      0.66      0.63       153
#
#     accuracy                           0.49       315
#    macro avg       0.42      0.33      0.34       315
# weighted avg       0.52      0.49      0.49       315

# %% [markdown]
# # Multinomial Naive Bayes Classification

# %%
#multiclass - one vs rest approach
# newton-cg : Ridge regress
model = LogisticRegression(multi_class='multinomial',solver='newton-cg',max_iter=10000)
model.fit(X,Y)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(max_iter=10000, multi_class='multinomial',
#                    solver='newton-cg')

# %%
Predicted_class = model.predict(X_test)
Predicted_class
# Out:
# array(['dependable', 'responsible', 'serious', 'serious', 'responsible',
#        'serious', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'responsible', 'responsible', 'serious', 'lively', 'extraverted',
#        'serious', 'serious', 'serious', 'extraverted', 'serious',
#        'extraverted', 'serious', 'extraverted', 'serious', 'serious',
#        'extraverted', 'extraverted', 'serious', 'responsible', 'serious',
#        'lively', 'extraverted', 'lively', 'serious', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'responsible', 'responsible',
#        'serious', 'lively', 'serious', 'serious', 'responsible',
#        'dependable', 'serious', 'extraverted', 'serious', 'serious',
#        'serious', 'lively', 'extraverted', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'responsible', 'serious',
#        'dependable', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'serious', 'responsible', 'extraverted', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'extraverted',
#        'extraverted', 'serious', 'lively', 'serious', 'serious',
#        'serious', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'extraverted', 'extraverted', 'extraverted',
#        'extraverted', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'serious', 'lively', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'serious',
#        'extraverted', 'lively', 'lively', 'serious', 'serious', 'lively',
#        'serious', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'dependable', 'serious', 'serious', 'dependable',
#        'serious', 'responsible', 'extraverted', 'serious', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'serious',
#        'extraverted', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'lively', 'extraverted', 'extraverted', 'serious',
#        'responsible', 'extraverted', 'serious', 'extraverted',
#        'responsible', 'extraverted', 'serious', 'serious', 'serious',
#        'responsible', 'serious', 'extraverted', 'extraverted',
#        'extraverted', 'serious', 'serious', 'serious', 'responsible',
#        'responsible', 'serious', 'serious', 'lively', 'serious',
#        'serious', 'serious', 'lively', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'lively', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'extraverted', 'serious',
#        'lively', 'serious', 'extraverted', 'serious', 'extraverted',
#        'responsible', 'serious', 'serious', 'serious', 'lively',
#        'serious', 'serious', 'serious', 'serious', 'extraverted',
#        'dependable', 'serious', 'extraverted', 'extraverted',
#        'extraverted', 'extraverted', 'lively', 'extraverted',
#        'extraverted', 'dependable', 'serious', 'dependable',
#        'extraverted', 'extraverted', 'extraverted', 'serious', 'serious',
#        'extraverted', 'serious', 'extraverted', 'extraverted',
#        'dependable', 'extraverted', 'serious', 'serious', 'extraverted',
#        'extraverted', 'serious', 'serious', 'extraverted', 'serious',
#        'serious', 'serious', 'serious', 'extraverted', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'responsible',
#        'extraverted', 'serious', 'extraverted', 'serious', 'extraverted',
#        'serious', 'responsible', 'responsible', 'extraverted', 'lively',
#        'serious', 'responsible', 'responsible', 'lively', 'lively',
#        'serious', 'extraverted', 'serious', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'extraverted', 'serious',
#        'responsible', 'responsible', 'extraverted', 'extraverted',
#        'serious', 'serious', 'responsible', 'extraverted', 'serious',
#        'extraverted', 'lively', 'dependable', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'extraverted', 'extraverted',
#        'extraverted', 'serious', 'extraverted', 'extraverted',
#        'extraverted', 'serious', 'extraverted', 'extraverted', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'serious', 'serious', 'serious', 'extraverted', 'serious',
#        'serious', 'extraverted', 'extraverted'], dtype=object)

# %%
print("Accuracy: ",metrics.accuracy_score(Y_test, Predicted_class)*100)
print("Confusion Matrix: ")
print(metrics.confusion_matrix(Y_test, Predicted_class))
print("Classification Report: ")
print(metrics.classification_report(Y_test,Predicted_class))
# Out:
# Accuracy:  84.12698412698413
# Confusion Matrix:
# [[  7   4   1   0   9]
#  [  0  70   1   0   6]
#  [  0   3  18   1   2]
#  [  2   4   0  26   8]
#  [  1   6   1   1 144]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   dependable       0.70      0.33      0.45        21
#  extraverted       0.80      0.91      0.85        77
#       lively       0.86      0.75      0.80        24
#  responsible       0.93      0.65      0.76        40
#      serious       0.85      0.94      0.89       153
#
#     accuracy                           0.84       315
#    macro avg       0.83      0.72      0.75       315
# weighted avg       0.84      0.84      0.83       315

# %%
clf = DecisionTreeClassifier(criterion='gini',max_depth=30,splitter='best')
clf.fit(X,Y)
Predicted_class = clf.predict(X_test)

# %%
Predicted_class
# Out:
# array(['lively', 'dependable', 'serious', 'dependable', 'serious',
#        'serious', 'extraverted', 'dependable', 'extraverted', 'serious',
#        'dependable', 'responsible', 'extraverted', 'serious', 'serious',
#        'dependable', 'lively', 'serious', 'extraverted', 'dependable',
#        'serious', 'serious', 'extraverted', 'dependable', 'responsible',
#        'lively', 'serious', 'dependable', 'dependable', 'responsible',
#        'lively', 'lively', 'dependable', 'dependable', 'responsible',
#        'responsible', 'lively', 'serious', 'responsible', 'dependable',
#        'lively', 'serious', 'serious', 'lively', 'dependable',
#        'responsible', 'dependable', 'lively', 'lively', 'extraverted',
#        'dependable', 'serious', 'serious', 'extraverted', 'responsible',
#        'dependable', 'serious', 'lively', 'responsible', 'serious',
#        'lively', 'lively', 'dependable', 'extraverted', 'extraverted',
#        'extraverted', 'responsible', 'dependable', 'responsible',
#        'extraverted', 'serious', 'extraverted', 'serious', 'responsible',
#        'dependable', 'dependable', 'extraverted', 'dependable', 'serious',
#        'extraverted', 'serious', 'serious', 'lively', 'dependable',
#        'responsible', 'dependable', 'extraverted', 'dependable',
#        'dependable', 'lively', 'dependable', 'responsible', 'lively',
#        'responsible', 'responsible', 'lively', 'serious', 'extraverted',
#        'extraverted', 'lively', 'extraverted', 'responsible', 'lively',
#        'extraverted', 'serious', 'responsible', 'responsible',
#        'responsible', 'dependable', 'serious', 'serious', 'extraverted',
#        'serious', 'extraverted', 'responsible', 'extraverted',
#        'responsible', 'extraverted', 'responsible', 'extraverted',
#        'lively', 'lively', 'serious', 'extraverted', 'serious',
#        'extraverted', 'serious', 'dependable', 'serious', 'lively',
#        'dependable', 'extraverted', 'responsible', 'lively',
#        'extraverted', 'extraverted', 'lively', 'lively', 'responsible',
#        'dependable', 'extraverted', 'lively', 'dependable', 'responsible',
#        'lively', 'responsible', 'lively', 'serious', 'extraverted',
#        'serious', 'responsible', 'extraverted', 'extraverted',
#        'dependable', 'responsible', 'lively', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'extraverted', 'dependable',
#        'serious', 'extraverted', 'dependable', 'serious', 'responsible',
#        'serious', 'responsible', 'serious', 'serious', 'responsible',
#        'responsible', 'responsible', 'responsible', 'serious',
#        'responsible', 'dependable', 'serious', 'serious', 'dependable',
#        'extraverted', 'serious', 'extraverted', 'lively', 'responsible',
#        'lively', 'dependable', 'dependable', 'responsible', 'extraverted',
#        'extraverted', 'responsible', 'lively', 'responsible',
#        'extraverted', 'responsible', 'lively', 'responsible', 'serious',
#        'serious', 'responsible', 'lively', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'extraverted', 'responsible',
#        'dependable', 'serious', 'extraverted', 'serious', 'dependable',
#        'serious', 'lively', 'lively', 'responsible', 'extraverted',
#        'serious', 'extraverted', 'serious', 'extraverted', 'serious',
#        'lively', 'responsible', 'lively', 'serious', 'lively', 'serious',
#        'serious', 'extraverted', 'responsible', 'serious', 'extraverted',
#        'responsible', 'serious', 'serious', 'extraverted', 'serious',
#        'lively', 'serious', 'serious', 'extraverted', 'extraverted',
#        'dependable', 'responsible', 'dependable', 'lively', 'dependable',
#        'responsible', 'dependable', 'dependable', 'serious',
#        'extraverted', 'responsible', 'lively', 'lively', 'serious',
#        'responsible', 'responsible', 'lively', 'responsible', 'lively',
#        'extraverted', 'serious', 'lively', 'responsible', 'serious',
#        'lively', 'lively', 'lively', 'responsible', 'dependable',
#        'dependable', 'serious', 'extraverted', 'extraverted', 'lively',
#        'serious', 'serious', 'responsible', 'extraverted', 'serious',
#        'extraverted', 'extraverted', 'dependable', 'extraverted',
#        'dependable', 'lively', 'responsible', 'serious', 'dependable',
#        'serious', 'lively', 'responsible', 'responsible', 'responsible',
#        'extraverted', 'dependable', 'dependable', 'serious', 'dependable',
#        'extraverted', 'extraverted', 'extraverted', 'dependable',
#        'lively', 'serious', 'serious', 'extraverted', 'serious',
#        'extraverted', 'serious'], dtype=object)

# %%
tree.plot_tree(clf)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# [Text(0.5586610417589627, 0.9772727272727273, 'X[5] <= 1.006\ngini = 0.798\nsamples = 709\nvalue = [138, 150, 134, 126, 161]'),
#  Text(0.24237320129327972, 0.9318181818181818, 'X[6] <= -0.687\ngini = 0.798\nsamples = 602\nvalue = [106, 118, 124, 111, 143]'),
#  Text(0.07585025899672847, 0.8863636363636364, 'X[2] <= -0.962\ngini = 0.786\nsamples = 170\nvalue = [18, 42, 42, 37, 31]'),
#  Text(0.017448200654307525, 0.8409090909090909, 'X[2] <= -1.618\ngini = 0.699\nsamples = 23\nvalue = [2, 3, 4, 11, 3]'),
#  Text(0.008724100327153763, 0.7954545454545454, 'X[4] <= -1.269\ngini = 0.667\nsamples = 6\nvalue = [1, 0, 1, 1, 3]'),
#  Text(0.004362050163576881, 0.75, 'X[5] <= 0.402\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0]'),
#  Text(0.0021810250817884407, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.006543075245365322, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.013086150490730643, 0.75, 'X[4] <= -0.691\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 0, 3]'),
#  Text(0.010905125408942203, 0.7045454545454546, 'X[6] <= -1.653\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1]'),
#  Text(0.008724100327153763, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.013086150490730643, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.015267175572519083, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.026172300981461286, 0.7954545454545454, 'X[1] <= 0.447\ngini = 0.588\nsamples = 17\nvalue = [1, 3, 3, 10, 0]'),
#  Text(0.021810250817884406, 0.75, 'X[1] <= -0.14\ngini = 0.462\nsamples = 13\nvalue = [1, 3, 0, 9, 0]'),
#  Text(0.019629225736095966, 0.7045454545454546, 'X[6] <= -1.331\ngini = 0.403\nsamples = 12\nvalue = [1, 2, 0, 9, 0]'),
#  Text(0.017448200654307525, 0.6590909090909091, 'X[3] <= 0.511\ngini = 0.571\nsamples = 7\nvalue = [1, 2, 0, 4, 0]'),
#  Text(0.015267175572519083, 0.6136363636363636, 'X[1] <= -0.531\ngini = 0.5\nsamples = 6\nvalue = [1, 1, 0, 4, 0]'),
#  Text(0.013086150490730643, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.017448200654307525, 0.5681818181818182, 'X[0] <= 0.051\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 1, 0]'),
#  Text(0.015267175572519083, 0.5227272727272727, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0]'),
#  Text(0.019629225736095966, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.019629225736095966, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.021810250817884406, 0.6590909090909091, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0]'),
#  Text(0.023991275899672846, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.030534351145038167, 0.75, 'X[6] <= -1.331\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0]'),
#  Text(0.028353326063249727, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.03271537622682661, 0.7045454545454546, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.1342523173391494, 0.8409090909090909, 'X[4] <= -0.113\ngini = 0.783\nsamples = 147\nvalue = [16, 39, 38, 26, 28]'),
#  Text(0.06761177753544166, 0.7954545454545454, 'X[5] <= -0.201\ngini = 0.734\nsamples = 70\nvalue = [3, 21, 23, 17, 6]'),
#  Text(0.04580152671755725, 0.75, 'X[1] <= -0.531\ngini = 0.628\nsamples = 28\nvalue = [1, 15, 4, 7, 1]'),
#  Text(0.03707742639040349, 0.7045454545454546, 'X[4] <= -0.691\ngini = 0.292\nsamples = 12\nvalue = [1, 10, 0, 1, 0]'),
#  Text(0.03489640130861505, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.03925845147219193, 0.6590909090909091, 'X[3] <= 1.096\ngini = 0.406\nsamples = 8\nvalue = [1, 6, 0, 1, 0]'),
#  Text(0.03489640130861505, 0.6136363636363636, 'X[2] <= 0.349\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 0, 1, 0]'),
#  Text(0.03271537622682661, 0.5681818181818182, 'X[1] <= -0.923\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0]'),
#  Text(0.030534351145038167, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.03489640130861505, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.03707742639040349, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.04362050163576881, 0.6136363636363636, 'X[0] <= 0.051\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0]'),
#  Text(0.04143947655398037, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.04580152671755725, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.05452562704471101, 0.7045454545454546, 'X[6] <= -1.974\ngini = 0.695\nsamples = 16\nvalue = [0, 5, 4, 6, 1]'),
#  Text(0.05234460196292257, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.05670665212649945, 0.6590909090909091, 'X[4] <= -0.691\ngini = 0.698\nsamples = 13\nvalue = [0, 5, 4, 3, 1]'),
#  Text(0.05452562704471101, 0.6136363636363636, 'X[3] <= -0.368\ngini = 0.645\nsamples = 11\nvalue = [0, 5, 4, 1, 1]'),
#  Text(0.05016357688113413, 0.5681818181818182, 'X[3] <= -1.246\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1]'),
#  Text(0.04798255179934569, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.05234460196292257, 0.5227272727272727, 'X[2] <= -0.307\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1]'),
#  Text(0.05016357688113413, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.05452562704471101, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.05888767720828789, 0.5681818181818182, 'X[2] <= 0.349\ngini = 0.408\nsamples = 7\nvalue = [0, 5, 2, 0, 0]'),
#  Text(0.05670665212649945, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.061068702290076333, 0.5227272727272727, 'X[5] <= -0.804\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0]'),
#  Text(0.05888767720828789, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.06324972737186478, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.05888767720828789, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.08942202835332606, 0.75, 'X[6] <= -1.331\ngini = 0.702\nsamples = 42\nvalue = [2, 6, 19, 10, 5]'),
#  Text(0.07306434023991276, 0.7045454545454546, 'X[6] <= -1.974\ngini = 0.669\nsamples = 27\nvalue = [0, 4, 11, 10, 2]'),
#  Text(0.06543075245365322, 0.6590909090909091, 'X[5] <= 0.402\ngini = 0.642\nsamples = 9\nvalue = [0, 3, 4, 0, 2]'),
#  Text(0.06324972737186478, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]'),
#  Text(0.06761177753544166, 0.6136363636363636, 'X[3] <= -0.953\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 0, 0, 2]'),
#  Text(0.06543075245365322, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.0697928026172301, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.0806979280261723, 0.6590909090909091, 'X[4] <= -0.691\ngini = 0.537\nsamples = 18\nvalue = [0, 1, 7, 10, 0]'),
#  Text(0.07633587786259542, 0.6136363636363636, 'X[1] <= -0.923\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 5, 3, 0]'),
#  Text(0.07415485278080698, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.07851690294438386, 0.5681818181818182, 'X[5] <= 0.402\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 5, 3, 0]'),
#  Text(0.07633587786259542, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.0806979280261723, 0.5227272727272727, 'X[2] <= 0.349\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0]'),
#  Text(0.07851690294438386, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.08287895310796074, 0.4772727272727273, 'X[3] <= 0.218\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0]'),
#  Text(0.0806979280261723, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.08505997818974918, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.08505997818974918, 0.6136363636363636, 'X[5] <= 0.402\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0]'),
#  Text(0.08287895310796074, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0]'),
#  Text(0.08724100327153762, 0.5681818181818182, 'X[3] <= -0.368\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0]'),
#  Text(0.08505997818974918, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.08942202835332606, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.10577971646673937, 0.7045454545454546, 'X[4] <= -0.691\ngini = 0.64\nsamples = 15\nvalue = [2, 2, 8, 0, 3]'),
#  Text(0.09814612868047982, 0.6590909090909091, 'X[1] <= -0.531\ngini = 0.722\nsamples = 6\nvalue = [2, 1, 1, 0, 2]'),
#  Text(0.09378407851690294, 0.6136363636363636, 'X[4] <= -1.558\ngini = 0.625\nsamples = 4\nvalue = [1, 1, 0, 0, 2]'),
#  Text(0.0916030534351145, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.09596510359869138, 0.5681818181818182, 'X[5] <= 0.402\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 2]'),
#  Text(0.09378407851690294, 0.5227272727272727, 'X[3] <= -0.368\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1]'),
#  Text(0.0916030534351145, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.09596510359869138, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.09814612868047982, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.1025081788440567, 0.6136363636363636, 'X[2] <= 0.677\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0]'),
#  Text(0.10032715376226826, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.10468920392584515, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.1134133042529989, 0.6590909090909091, 'X[3] <= 0.511\ngini = 0.37\nsamples = 9\nvalue = [0, 1, 7, 0, 1]'),
#  Text(0.11123227917121047, 0.6136363636363636, 'X[1] <= -0.531\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 0, 1]'),
#  Text(0.10905125408942203, 0.5681818181818182, 'X[0] <= 0.051\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1]'),
#  Text(0.10687022900763359, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.11123227917121047, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.1134133042529989, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.11559432933478735, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.20089285714285715, 0.7954545454545454, 'X[1] <= 1.035\ngini = 0.784\nsamples = 77\nvalue = [13, 18, 15, 9, 22]'),
#  Text(0.17386859323882226, 0.75, 'X[3] <= 0.511\ngini = 0.779\nsamples = 70\nvalue = [12, 14, 14, 8, 22]'),
#  Text(0.14326608505997818, 0.7045454545454546, 'X[1] <= -0.923\ngini = 0.753\nsamples = 44\nvalue = [3, 8, 12, 6, 15]'),
#  Text(0.12431842966194111, 0.6590909090909091, 'X[5] <= -0.502\ngini = 0.653\nsamples = 7\nvalue = [0, 3, 2, 2, 0]'),
#  Text(0.11995637949836423, 0.6136363636363636, 'X[2] <= 0.349\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0, 0]'),
#  Text(0.11777535441657579, 0.5681818181818182, 'X[0] <= 0.051\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.11559432933478735, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.11995637949836423, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.12213740458015267, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.128680479825518, 0.6136363636363636, 'X[0] <= 0.051\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0]'),
#  Text(0.12649945474372956, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.13086150490730644, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.16221374045801526, 0.6590909090909091, 'X[3] <= -0.075\ngini = 0.726\nsamples = 37\nvalue = [3, 5, 10, 4, 15]'),
#  Text(0.14558342420937842, 0.6136363636363636, 'X[2] <= 0.349\ngini = 0.735\nsamples = 18\nvalue = [2, 2, 7, 2, 5]'),
#  Text(0.13522355507088332, 0.5681818181818182, 'X[4] <= 0.465\ngini = 0.625\nsamples = 12\nvalue = [0, 0, 5, 2, 5]'),
#  Text(0.1297709923664122, 0.5227272727272727, 'X[6] <= -1.653\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0]'),
#  Text(0.12758996728462377, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.13195201744820065, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.1406761177753544, 0.5227272727272727, 'X[5] <= -0.201\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 4, 0, 5]'),
#  Text(0.13631406761177753, 0.4772727272727273, 'X[3] <= -0.953\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1]'),
#  Text(0.1341330425299891, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.13849509269356597, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.1450381679389313, 0.4772727272727273, 'X[5] <= 0.402\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4]'),
#  Text(0.14285714285714285, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.14721919302071973, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.1559432933478735, 0.5681818181818182, 'X[4] <= 1.043\ngini = 0.667\nsamples = 6\nvalue = [2, 2, 2, 0, 0]'),
#  Text(0.1515812431842966, 0.5227272727272727, 'X[3] <= -0.66\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0]'),
#  Text(0.14940021810250817, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.15376226826608505, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.16030534351145037, 0.5227272727272727, 'X[5] <= -0.804\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0, 0]'),
#  Text(0.15812431842966193, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.1624863685932388, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.17884405670665213, 0.6136363636363636, 'X[2] <= 1.005\ngini = 0.659\nsamples = 19\nvalue = [1, 3, 3, 2, 10]'),
#  Text(0.173391494002181, 0.5681818181818182, 'X[6] <= -1.331\ngini = 0.678\nsamples = 11\nvalue = [1, 3, 0, 2, 5]'),
#  Text(0.16902944383860413, 0.5227272727272727, 'X[4] <= 0.465\ngini = 0.611\nsamples = 6\nvalue = [0, 3, 0, 2, 1]'),
#  Text(0.1668484187568157, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.17121046892039257, 0.4772727272727273, 'X[5] <= -0.502\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1]'),
#  Text(0.16902944383860413, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.173391494002181, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.1777535441657579, 0.5227272727272727, 'X[4] <= 0.754\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 0, 0, 4]'),
#  Text(0.17557251908396945, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.17993456924754633, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.18429661941112324, 0.5681818181818182, 'X[6] <= -1.974\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 0, 5]'),
#  Text(0.1821155943293348, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.18647764449291168, 0.5227272727272727, 'X[5] <= -1.106\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 0, 3]'),
#  Text(0.18429661941112324, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.18865866957470012, 0.4772727272727273, 'X[4] <= 1.043\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 0, 2]'),
#  Text(0.18647764449291168, 0.4318181818181818, 'X[5] <= -0.201\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2]'),
#  Text(0.18429661941112324, 0.38636363636363635, 'X[4] <= 0.465\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1]'),
#  Text(0.1821155943293348, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.18647764449291168, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.18865866957470012, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.19083969465648856, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.2044711014176663, 0.7045454545454546, 'X[6] <= -1.331\ngini = 0.743\nsamples = 26\nvalue = [9, 6, 2, 2, 7]'),
#  Text(0.193020719738277, 0.6590909090909091, 'X[5] <= -0.201\ngini = 0.568\nsamples = 9\nvalue = [5, 3, 1, 0, 0]'),
#  Text(0.19083969465648856, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]'),
#  Text(0.19520174482006544, 0.6136363636363636, 'X[0] <= 0.051\ngini = 0.56\nsamples = 5\nvalue = [1, 3, 1, 0, 0]'),
#  Text(0.193020719738277, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.19738276990185388, 0.5681818181818182, 'X[2] <= 0.677\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 1, 0, 0]'),
#  Text(0.19520174482006544, 0.5227272727272727, 'X[3] <= 1.096\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0]'),
#  Text(0.193020719738277, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.19738276990185388, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.19956379498364232, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.2159214830970556, 0.6590909090909091, 'X[3] <= 1.096\ngini = 0.727\nsamples = 17\nvalue = [4, 3, 1, 2, 7]'),
#  Text(0.21046892039258452, 0.6136363636363636, 'X[4] <= 1.043\ngini = 0.72\nsamples = 10\nvalue = [4, 2, 0, 2, 2]'),
#  Text(0.20610687022900764, 0.5681818181818182, 'X[1] <= 0.252\ngini = 0.571\nsamples = 7\nvalue = [4, 0, 0, 2, 1]'),
#  Text(0.2039258451472192, 0.5227272727272727, 'X[5] <= -0.201\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2, 0]'),
#  Text(0.20174482006543076, 0.4772727272727273, 'X[5] <= -0.804\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0]'),
#  Text(0.19956379498364232, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.2039258451472192, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.20610687022900764, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]'),
#  Text(0.20828789531079608, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.2148309705561614, 0.5681818181818182, 'X[2] <= 0.677\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1]'),
#  Text(0.21264994547437296, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.21701199563794984, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.22137404580152673, 0.6136363636363636, 'X[5] <= -0.201\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 1, 0, 5]'),
#  Text(0.21919302071973829, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.22355507088331517, 0.5681818181818182, 'X[0] <= 0.051\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 0, 5]'),
#  Text(0.22137404580152673, 0.5227272727272727, 'X[1] <= -0.14\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1]'),
#  Text(0.21919302071973829, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.22355507088331517, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.2257360959651036, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.22791712104689205, 0.75, 'X[5] <= -0.804\ngini = 0.612\nsamples = 7\nvalue = [1, 4, 1, 1, 0]'),
#  Text(0.2257360959651036, 0.7045454545454546, 'X[5] <= -2.01\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 1, 1, 0]'),
#  Text(0.22355507088331517, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.22791712104689205, 0.6590909090909091, 'X[0] <= 0.051\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0]'),
#  Text(0.2257360959651036, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.2300981461286805, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.2300981461286805, 0.7045454545454546, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.40889614358983095, 0.8863636363636364, 'X[5] <= -1.407\ngini = 0.795\nsamples = 432\nvalue = [88, 76, 82, 74, 112]'),
#  Text(0.2837377317339149, 0.8409090909090909, 'X[2] <= 1.005\ngini = 0.757\nsamples = 55\nvalue = [19, 7, 8, 6, 15]'),
#  Text(0.2675845147219193, 0.7954545454545454, 'X[4] <= 0.465\ngini = 0.782\nsamples = 41\nvalue = [10, 7, 7, 5, 12]'),
#  Text(0.2538167938931298, 0.75, 'X[6] <= 1.243\ngini = 0.787\nsamples = 25\nvalue = [3, 6, 6, 4, 6]'),
#  Text(0.24263904034896402, 0.7045454545454546, 'X[6] <= -0.044\ngini = 0.747\nsamples = 17\nvalue = [2, 2, 6, 2, 5]'),
#  Text(0.2366412213740458, 0.6590909090909091, 'X[2] <= -0.307\ngini = 0.64\nsamples = 5\nvalue = [2, 1, 0, 0, 2]'),
#  Text(0.23446019629225737, 0.6136363636363636, 'X[4] <= -0.691\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 2]'),
#  Text(0.23227917121046893, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.2366412213740458, 0.5681818181818182, 'X[1] <= 0.252\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1]'),
#  Text(0.23446019629225737, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.23882224645583425, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.23882224645583425, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.24863685932388221, 0.6590909090909091, 'X[3] <= -0.075\ngini = 0.653\nsamples = 12\nvalue = [0, 1, 6, 2, 3]'),
#  Text(0.24318429661941113, 0.6136363636363636, 'X[2] <= 0.349\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 0, 1]'),
#  Text(0.2410032715376227, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.24536532170119957, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.25408942202835333, 0.6136363636363636, 'X[5] <= -2.01\ngini = 0.722\nsamples = 6\nvalue = [0, 1, 1, 2, 2]'),
#  Text(0.24972737186477645, 0.5681818181818182, 'X[3] <= 1.096\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0]'),
#  Text(0.247546346782988, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.25190839694656486, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.2584514721919302, 0.5681818181818182, 'X[3] <= 0.803\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2]'),
#  Text(0.25627044711014174, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.2606324972737186, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.2649945474372955, 0.7045454545454546, 'X[2] <= -0.962\ngini = 0.656\nsamples = 8\nvalue = [1, 4, 0, 2, 1]'),
#  Text(0.2628135223555071, 0.6590909090909091, 'X[4] <= -0.113\ngini = 0.625\nsamples = 4\nvalue = [1, 0, 0, 2, 1]'),
#  Text(0.2606324972737186, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.2649945474372955, 0.6136363636363636, 'X[1] <= 0.056\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1]'),
#  Text(0.2628135223555071, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.26717557251908397, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.26717557251908397, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.2813522355507088, 0.75, 'X[2] <= -0.962\ngini = 0.656\nsamples = 16\nvalue = [7, 1, 1, 1, 6]'),
#  Text(0.27589967284623773, 0.7045454545454546, 'X[4] <= 1.043\ngini = 0.716\nsamples = 9\nvalue = [2, 1, 1, 1, 4]'),
#  Text(0.2737186477644493, 0.6590909090909091, 'X[6] <= -0.044\ngini = 0.656\nsamples = 8\nvalue = [2, 0, 1, 1, 4]'),
#  Text(0.27153762268266085, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.27589967284623773, 0.6136363636363636, 'X[1] <= 0.839\ngini = 0.612\nsamples = 7\nvalue = [1, 0, 1, 1, 4]'),
#  Text(0.27153762268266085, 0.5681818181818182, 'X[5] <= -2.01\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 0, 3]'),
#  Text(0.2693565976008724, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.2737186477644493, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.2802617230098146, 0.5681818181818182, 'X[3] <= 0.511\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1]'),
#  Text(0.2780806979280262, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.2824427480916031, 0.5227272727272727, 'X[1] <= 1.622\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0]'),
#  Text(0.2802617230098146, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.2846237731733915, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.2780806979280262, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.28680479825517996, 0.7045454545454546, 'X[2] <= 0.349\ngini = 0.408\nsamples = 7\nvalue = [5, 0, 0, 0, 2]'),
#  Text(0.2846237731733915, 0.6590909090909091, 'X[1] <= -0.531\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 0, 0, 2]'),
#  Text(0.2824427480916031, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.28680479825517996, 0.6136363636363636, 'X[4] <= 1.043\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 0, 1]'),
#  Text(0.2846237731733915, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]'),
#  Text(0.2889858233369684, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.2889858233369684, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.2998909487459106, 0.7954545454545454, 'X[4] <= 1.043\ngini = 0.531\nsamples = 14\nvalue = [9, 0, 1, 1, 3]'),
#  Text(0.29770992366412213, 0.75, 'X[2] <= 1.66\ngini = 0.417\nsamples = 12\nvalue = [9, 0, 1, 1, 1]'),
#  Text(0.2955288985823337, 0.7045454545454546, 'X[6] <= 0.599\ngini = 0.314\nsamples = 11\nvalue = [9, 0, 0, 1, 1]'),
#  Text(0.29334787350054525, 0.6590909090909091, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0, 0]'),
#  Text(0.29770992366412213, 0.6590909090909091, 'X[0] <= 0.051\ngini = 0.56\nsamples = 5\nvalue = [3, 0, 0, 1, 1]'),
#  Text(0.2955288985823337, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.2998909487459106, 0.6136363636363636, 'X[3] <= -0.075\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 0, 1, 1]'),
#  Text(0.29770992366412213, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.302071973827699, 0.5681818181818182, 'X[1] <= -0.14\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1]'),
#  Text(0.2998909487459106, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.3042529989094875, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.2998909487459106, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.302071973827699, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.534054555445747, 0.8409090909090909, 'X[4] <= -0.113\ngini = 0.796\nsamples = 377\nvalue = [69, 69, 74, 68, 97]'),
#  Text(0.4247546346782988, 0.7954545454545454, 'X[5] <= 0.402\ngini = 0.777\nsamples = 149\nvalue = [25, 28, 19, 28, 49]'),
#  Text(0.3822246455834242, 0.75, 'X[3] <= 1.096\ngini = 0.781\nsamples = 105\nvalue = [21, 21, 10, 23, 30]'),
#  Text(0.35659760087241005, 0.7045454545454546, 'X[4] <= -1.269\ngini = 0.782\nsamples = 95\nvalue = [21, 16, 10, 21, 27]'),
#  Text(0.3287895310796074, 0.6590909090909091, 'X[2] <= 0.349\ngini = 0.778\nsamples = 29\nvalue = [9, 7, 4, 5, 4]'),
#  Text(0.3107960741548528, 0.6136363636363636, 'X[1] <= -0.923\ngini = 0.755\nsamples = 14\nvalue = [2, 5, 1, 3, 3]'),
#  Text(0.30861504907306436, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.31297709923664124, 0.5681818181818182, 'X[4] <= -1.848\ngini = 0.746\nsamples = 13\nvalue = [2, 5, 1, 3, 2]'),
#  Text(0.30861504907306436, 0.5227272727272727, 'X[1] <= 0.643\ngini = 0.694\nsamples = 7\nvalue = [1, 3, 1, 0, 2]'),
#  Text(0.3064340239912759, 0.4772727272727273, 'X[5] <= -0.502\ngini = 0.72\nsamples = 5\nvalue = [1, 1, 1, 0, 2]'),
#  Text(0.302071973827699, 0.4318181818181818, 'X[0] <= 0.051\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0]'),
#  Text(0.2998909487459106, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.3042529989094875, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.3107960741548528, 0.4318181818181818, 'X[1] <= -0.531\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 2]'),
#  Text(0.30861504907306436, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.31297709923664124, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.3107960741548528, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.3173391494002181, 0.5227272727272727, 'X[3] <= -0.66\ngini = 0.611\nsamples = 6\nvalue = [1, 2, 0, 3, 0]'),
#  Text(0.31515812431842966, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.31952017448200654, 0.4772727272727273, 'X[2] <= -0.962\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 0, 1, 0]'),
#  Text(0.3173391494002181, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.321701199563795, 0.4318181818181818, 'X[6] <= 0.599\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0]'),
#  Text(0.31952017448200654, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3238822246455834, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.346782988004362, 0.6136363636363636, 'X[4] <= -1.848\ngini = 0.702\nsamples = 15\nvalue = [7, 2, 3, 2, 1]'),
#  Text(0.34242093784078514, 0.5681818181818182, 'X[3] <= 0.511\ngini = 0.75\nsamples = 8\nvalue = [2, 1, 3, 1, 1]'),
#  Text(0.34023991275899673, 0.5227272727272727, 'X[2] <= 1.005\ngini = 0.694\nsamples = 7\nvalue = [2, 1, 3, 1, 0]'),
#  Text(0.33478735005452565, 0.4772727272727273, 'X[3] <= -0.368\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 3, 1, 0]'),
#  Text(0.33042529989094876, 0.4318181818181818, 'X[6] <= 0.599\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0, 0]'),
#  Text(0.3282442748091603, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.3326063249727372, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.3391494002181025, 0.4318181818181818, 'X[5] <= -0.804\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0]'),
#  Text(0.33696837513631406, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.34133042529989094, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3456924754634678, 0.4772727272727273, 'X[6] <= 0.278\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0]'),
#  Text(0.3435114503816794, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.3478735005452563, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.3446019629225736, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.3511450381679389, 0.5681818181818182, 'X[6] <= -0.044\ngini = 0.449\nsamples = 7\nvalue = [5, 1, 0, 1, 0]'),
#  Text(0.3489640130861505, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3533260632497274, 0.5227272727272727, 'X[6] <= 1.243\ngini = 0.278\nsamples = 6\nvalue = [5, 1, 0, 0, 0]'),
#  Text(0.3511450381679389, 0.4772727272727273, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0, 0]'),
#  Text(0.3555070883315158, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.38440567066521264, 0.6590909090909091, 'X[4] <= -0.691\ngini = 0.76\nsamples = 66\nvalue = [12, 9, 6, 16, 23]'),
#  Text(0.3696837513631407, 0.6136363636363636, 'X[5] <= -0.804\ngini = 0.707\nsamples = 28\nvalue = [2, 5, 1, 10, 10]'),
#  Text(0.3642311886586696, 0.5681818181818182, 'X[1] <= 0.056\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 4, 0]'),
#  Text(0.36205016357688113, 0.5227272727272727, 'X[1] <= -0.531\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0]'),
#  Text(0.35986913849509267, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3642311886586696, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.366412213740458, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.3751363140676118, 0.5681818181818182, 'X[2] <= 0.349\ngini = 0.703\nsamples = 23\nvalue = [2, 4, 1, 6, 10]'),
#  Text(0.3707742639040349, 0.5227272727272727, 'X[3] <= 0.511\ngini = 0.637\nsamples = 19\nvalue = [2, 1, 1, 5, 10]'),
#  Text(0.3685932388222465, 0.4772727272727273, 'X[5] <= -0.201\ngini = 0.702\nsamples = 15\nvalue = [2, 1, 1, 5, 6]'),
#  Text(0.3642311886586696, 0.4318181818181818, 'X[6] <= 1.243\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 1, 0, 4]'),
#  Text(0.36205016357688113, 0.38636363636363635, 'X[1] <= -0.923\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 0, 4]'),
#  Text(0.35986913849509267, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.3642311886586696, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.366412213740458, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.37295528898582336, 0.4318181818181818, 'X[1] <= -0.531\ngini = 0.593\nsamples = 9\nvalue = [2, 0, 0, 5, 2]'),
#  Text(0.3707742639040349, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.3751363140676118, 0.38636363636363635, 'X[3] <= -1.246\ngini = 0.653\nsamples = 7\nvalue = [2, 0, 0, 3, 2]'),
#  Text(0.3707742639040349, 0.3409090909090909, 'X[0] <= 0.051\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1]'),
#  Text(0.3685932388222465, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.37295528898582336, 0.29545454545454547, 'X[6] <= -0.044\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1]'),
#  Text(0.3707742639040349, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3751363140676118, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.37949836423118866, 0.3409090909090909, 'X[3] <= -0.075\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 0, 1]'),
#  Text(0.37731733914940024, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.3816793893129771, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.37295528898582336, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.37949836423118866, 0.5227272727272727, 'X[1] <= 0.056\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1, 0]'),
#  Text(0.37731733914940024, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3816793893129771, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.39912758996728465, 0.6136363636363636, 'X[5] <= -0.804\ngini = 0.76\nsamples = 38\nvalue = [10, 4, 5, 6, 13]'),
#  Text(0.3904034896401309, 0.5681818181818182, 'X[3] <= 0.511\ngini = 0.562\nsamples = 8\nvalue = [0, 1, 1, 1, 5]'),
#  Text(0.3882224645583424, 0.5227272727272727, 'X[6] <= 0.599\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 0, 1, 5]'),
#  Text(0.386041439476554, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.3904034896401309, 0.4772727272727273, 'X[2] <= 1.005\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 0, 1, 2]'),
#  Text(0.3882224645583424, 0.4318181818181818, 'X[1] <= 0.056\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 2]'),
#  Text(0.386041439476554, 0.38636363636363635, 'X[2] <= 0.021\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1]'),
#  Text(0.38386041439476554, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.3882224645583424, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.3904034896401309, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.3925845147219193, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3925845147219193, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.4078516902944384, 0.5681818181818182, 'X[6] <= 0.599\ngini = 0.762\nsamples = 30\nvalue = [10, 3, 4, 5, 8]'),
#  Text(0.40130861504907306, 0.5227272727272727, 'X[2] <= 1.005\ngini = 0.735\nsamples = 21\nvalue = [6, 2, 3, 2, 8]'),
#  Text(0.39912758996728465, 0.4772727272727273, 'X[2] <= -0.307\ngini = 0.722\nsamples = 18\nvalue = [3, 2, 3, 2, 8]'),
#  Text(0.3969465648854962, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.40130861504907306, 0.4318181818181818, 'X[6] <= -0.044\ngini = 0.773\nsamples = 15\nvalue = [3, 2, 3, 2, 5]'),
#  Text(0.3969465648854962, 0.38636363636363635, 'X[2] <= 0.349\ngini = 0.653\nsamples = 7\nvalue = [3, 0, 2, 2, 0]'),
#  Text(0.39476553980370777, 0.3409090909090909, 'X[1] <= 0.839\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 0, 2, 0]'),
#  Text(0.3925845147219193, 0.29545454545454547, 'X[3] <= -0.368\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 2, 0]'),
#  Text(0.3904034896401309, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.39476553980370777, 0.25, 'X[1] <= -0.14\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0]'),
#  Text(0.3925845147219193, 0.20454545454545456, 'X[5] <= -0.201\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0]'),
#  Text(0.3904034896401309, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.39476553980370777, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3969465648854962, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3969465648854962, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.39912758996728465, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.40567066521264994, 0.38636363636363635, 'X[3] <= -0.075\ngini = 0.531\nsamples = 8\nvalue = [0, 2, 1, 0, 5]'),
#  Text(0.4034896401308615, 0.3409090909090909, 'X[2] <= 0.349\ngini = 0.625\nsamples = 4\nvalue = [0, 2, 1, 0, 1]'),
#  Text(0.40130861504907306, 0.29545454545454547, 'X[5] <= -0.201\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1]'),
#  Text(0.39912758996728465, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.4034896401308615, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.40567066521264994, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.4078516902944384, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.4034896401308615, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]'),
#  Text(0.4143947655398037, 0.5227272727272727, 'X[1] <= -0.14\ngini = 0.667\nsamples = 9\nvalue = [4, 1, 1, 3, 0]'),
#  Text(0.4100327153762268, 0.4772727272727273, 'X[1] <= -0.727\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0]'),
#  Text(0.4078516902944384, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.4122137404580153, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.4187568157033806, 0.4772727272727273, 'X[6] <= 1.243\ngini = 0.5\nsamples = 6\nvalue = [4, 0, 1, 1, 0]'),
#  Text(0.41657579062159217, 0.4318181818181818, 'X[1] <= 0.252\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1, 0]'),
#  Text(0.4143947655398037, 0.38636363636363635, 'X[0] <= 0.051\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1, 0]'),
#  Text(0.4122137404580153, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.41657579062159217, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.4187568157033806, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.42093784078516905, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.4078516902944384, 0.7045454545454546, 'X[1] <= 1.035\ngini = 0.62\nsamples = 10\nvalue = [0, 5, 0, 2, 3]'),
#  Text(0.40567066521264994, 0.6590909090909091, 'X[2] <= -0.307\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 2, 3]'),
#  Text(0.4034896401308615, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.4078516902944384, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.4100327153762268, 0.6590909090909091, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0]'),
#  Text(0.46728462377317337, 0.75, 'X[1] <= 0.643\ngini = 0.725\nsamples = 44\nvalue = [4, 7, 9, 5, 19]'),
#  Text(0.45038167938931295, 0.7045454545454546, 'X[1] <= -0.531\ngini = 0.687\nsamples = 37\nvalue = [2, 6, 7, 4, 18]'),
#  Text(0.4351145038167939, 0.6590909090909091, 'X[6] <= 0.599\ngini = 0.754\nsamples = 17\nvalue = [1, 4, 5, 2, 5]'),
#  Text(0.43293347873500543, 0.6136363636363636, 'X[1] <= -0.923\ngini = 0.745\nsamples = 14\nvalue = [1, 4, 5, 2, 2]'),
#  Text(0.42748091603053434, 0.5681818181818182, 'X[3] <= 1.096\ngini = 0.5\nsamples = 6\nvalue = [1, 1, 4, 0, 0]'),
#  Text(0.42529989094874593, 0.5227272727272727, 'X[4] <= -0.691\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0, 0]'),
#  Text(0.42311886586695746, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.42748091603053434, 0.4772727272727273, 'X[2] <= 0.349\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0]'),
#  Text(0.42529989094874593, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.4296619411123228, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.4296619411123228, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.43838604143947657, 0.5681818181818182, 'X[6] <= -0.044\ngini = 0.719\nsamples = 8\nvalue = [0, 3, 1, 2, 2]'),
#  Text(0.4340239912758997, 0.5227272727272727, 'X[4] <= -1.269\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 0, 0, 2]'),
#  Text(0.4318429661941112, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.4362050163576881, 0.4772727272727273, 'X[3] <= 0.511\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1]'),
#  Text(0.4340239912758997, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.43838604143947657, 0.4318181818181818, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1]'),
#  Text(0.44274809160305345, 0.5227272727272727, 'X[4] <= -0.691\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0]'),
#  Text(0.440567066521265, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.44492911668484186, 0.4772727272727273, 'X[3] <= -0.953\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.44274809160305345, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.44711014176663033, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.4372955288985823, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.46564885496183206, 0.6590909090909091, 'X[3] <= -0.075\ngini = 0.545\nsamples = 20\nvalue = [1, 2, 2, 2, 13]'),
#  Text(0.4580152671755725, 0.6136363636363636, 'X[3] <= -1.246\ngini = 0.625\nsamples = 8\nvalue = [0, 2, 2, 0, 4]'),
#  Text(0.4536532170119956, 0.5681818181818182, 'X[1] <= 0.056\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 0, 0, 3]'),
#  Text(0.4514721919302072, 0.5227272727272727, 'X[6] <= 1.243\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1]'),
#  Text(0.44929116684841874, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.4536532170119956, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.4558342420937841, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.4623773173391494, 0.5681818181818182, 'X[6] <= 0.278\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1]'),
#  Text(0.460196292257361, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.46455834242093785, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.4732824427480916, 0.6136363636363636, 'X[6] <= 1.243\ngini = 0.403\nsamples = 12\nvalue = [1, 0, 0, 2, 9]'),
#  Text(0.47110141766630315, 0.5681818181818182, 'X[4] <= -0.691\ngini = 0.314\nsamples = 11\nvalue = [1, 0, 0, 1, 9]'),
#  Text(0.46892039258451473, 0.5227272727272727, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7]'),
#  Text(0.4732824427480916, 0.5227272727272727, 'X[3] <= 0.511\ngini = 0.625\nsamples = 4\nvalue = [1, 0, 0, 1, 2]'),
#  Text(0.47110141766630315, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.47546346782988, 0.4772727272727273, 'X[6] <= 0.278\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0]'),
#  Text(0.4732824427480916, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.4776444929116685, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.47546346782988, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.4841875681570338, 0.7045454545454546, 'X[3] <= -1.246\ngini = 0.776\nsamples = 7\nvalue = [2, 1, 2, 1, 1]'),
#  Text(0.4820065430752454, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.48636859323882226, 0.6590909090909091, 'X[6] <= 0.599\ngini = 0.722\nsamples = 6\nvalue = [2, 1, 2, 0, 1]'),
#  Text(0.4820065430752454, 0.6136363636363636, 'X[6] <= -0.044\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0, 0]'),
#  Text(0.4798255179934569, 0.5681818181818182, 'X[1] <= 1.035\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0]'),
#  Text(0.4776444929116685, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.4820065430752454, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.4841875681570338, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.49073064340239914, 0.6136363636363636, 'X[0] <= 0.051\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 1]'),
#  Text(0.48854961832061067, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.49291166848418755, 0.5681818181818182, 'X[1] <= 2.209\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1]'),
#  Text(0.49073064340239914, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.495092693565976, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.6433544762131952, 0.7954545454545454, 'X[3] <= -1.246\ngini = 0.797\nsamples = 228\nvalue = [44, 41, 55, 40, 48]'),
#  Text(0.5092693565976009, 0.75, 'X[4] <= 1.043\ngini = 0.763\nsamples = 27\nvalue = [8, 6, 1, 6, 6]'),
#  Text(0.5016357688113413, 0.7045454545454546, 'X[5] <= -0.201\ngini = 0.747\nsamples = 18\nvalue = [2, 4, 1, 5, 6]'),
#  Text(0.49727371864776443, 0.6590909090909091, 'X[2] <= -0.962\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 0, 0, 4]'),
#  Text(0.495092693565976, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.4994547437295529, 0.6136363636363636, 'X[1] <= -0.14\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 0, 4]'),
#  Text(0.49727371864776443, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.5016357688113413, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.5059978189749182, 0.6590909090909091, 'X[6] <= -0.044\ngini = 0.711\nsamples = 11\nvalue = [2, 1, 1, 5, 2]'),
#  Text(0.5038167938931297, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.5081788440567067, 0.6136363636363636, 'X[2] <= 0.349\ngini = 0.617\nsamples = 9\nvalue = [2, 1, 1, 5, 0]'),
#  Text(0.5059978189749182, 0.5681818181818182, 'X[6] <= 0.599\ngini = 0.72\nsamples = 5\nvalue = [2, 1, 1, 1, 0]'),
# ...
#  Text(0.8298800436205016, 0.5227272727272727, 'X[2] <= 0.349\ngini = 0.778\nsamples = 6\nvalue = [1, 1, 1, 2, 1]'),
#  Text(0.8276990185387132, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.8320610687022901, 0.4772727272727273, 'X[0] <= 0.051\ngini = 0.75\nsamples = 4\nvalue = [1, 1, 1, 0, 1]'),
#  Text(0.8276990185387132, 0.4318181818181818, 'X[3] <= 0.511\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1]'),
#  Text(0.8255179934569248, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.8298800436205016, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.836423118865867, 0.4318181818181818, 'X[4] <= 0.754\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0]'),
#  Text(0.8342420937840785, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8386041439476554, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.8386041439476554, 0.5227272727272727, 'X[2] <= -0.307\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0, 0, 0]'),
#  Text(0.836423118865867, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.8407851690294439, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.8429661941112323, 0.7045454545454546, 'X[5] <= -0.804\ngini = 0.531\nsamples = 8\nvalue = [2, 0, 5, 1, 0]'),
#  Text(0.8407851690294439, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.8451472191930207, 0.6590909090909091, 'X[6] <= -0.044\ngini = 0.449\nsamples = 7\nvalue = [1, 0, 5, 1, 0]'),
#  Text(0.8429661941112323, 0.6136363636363636, 'X[2] <= -0.962\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 1, 1, 0]'),
#  Text(0.8407851690294439, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.8451472191930207, 0.5681818181818182, 'X[3] <= -0.075\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0]'),
#  Text(0.8429661941112323, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.8473282442748091, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.8473282442748091, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]'),
#  Text(0.8749488822246456, 0.9318181818181818, 'X[6] <= -0.687\ngini = 0.764\nsamples = 107\nvalue = [32, 32, 10, 15, 18]'),
#  Text(0.8560523446019629, 0.8863636363636364, 'X[3] <= -0.075\ngini = 0.649\nsamples = 22\nvalue = [12, 3, 3, 2, 2]'),
#  Text(0.8473282442748091, 0.8409090909090909, 'X[2] <= -0.962\ngini = 0.694\nsamples = 7\nvalue = [2, 1, 3, 0, 1]'),
#  Text(0.8429661941112323, 0.7954545454545454, 'X[1] <= -0.14\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1]'),
#  Text(0.8407851690294439, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.8451472191930207, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8516902944383861, 0.7954545454545454, 'X[0] <= 0.051\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 3, 0, 0]'),
#  Text(0.8495092693565977, 0.75, 'X[3] <= -1.246\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0, 0]'),
#  Text(0.8473282442748091, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.8516902944383861, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.8538713195201745, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.8647764449291166, 0.8409090909090909, 'X[0] <= 0.051\ngini = 0.516\nsamples = 15\nvalue = [10, 2, 0, 2, 1]'),
#  Text(0.8604143947655398, 0.7954545454545454, 'X[1] <= -0.923\ngini = 0.625\nsamples = 8\nvalue = [4, 2, 0, 2, 0]'),
#  Text(0.8582333696837514, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.8625954198473282, 0.75, 'X[2] <= -0.307\ngini = 0.667\nsamples = 6\nvalue = [2, 2, 0, 2, 0]'),
#  Text(0.8604143947655398, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8647764449291166, 0.7045454545454546, 'X[4] <= 0.754\ngini = 0.64\nsamples = 5\nvalue = [2, 1, 0, 2, 0]'),
#  Text(0.8625954198473282, 0.6590909090909091, 'X[4] <= -0.113\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 2, 0]'),
#  Text(0.8604143947655398, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.8647764449291166, 0.6136363636363636, 'X[1] <= -0.531\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1, 0]'),
#  Text(0.8625954198473282, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.8669574700109052, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.8669574700109052, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8691384950926936, 0.7954545454545454, 'X[1] <= -0.14\ngini = 0.245\nsamples = 7\nvalue = [6, 0, 0, 0, 1]'),
#  Text(0.8669574700109052, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.871319520174482, 0.75, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0, 0]'),
#  Text(0.8938454198473282, 0.8863636363636364, 'X[2] <= -2.274\ngini = 0.763\nsamples = 85\nvalue = [20, 29, 7, 13, 16]'),
#  Text(0.8756815703380589, 0.8409090909090909, 'X[6] <= -0.044\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3, 0]'),
#  Text(0.8735005452562704, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.8778625954198473, 0.7954545454545454, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.9120092693565977, 0.8409090909090909, 'X[3] <= -1.831\ngini = 0.755\nsamples = 81\nvalue = [19, 29, 7, 10, 16]'),
#  Text(0.8822246455834242, 0.7954545454545454, 'X[6] <= 1.243\ngini = 0.7\nsamples = 10\nvalue = [0, 2, 1, 4, 3]'),
#  Text(0.8800436205016358, 0.75, 'X[1] <= -0.14\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 1, 4, 3]'),
#  Text(0.8756815703380589, 0.7045454545454546, 'X[4] <= -1.848\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1]'),
#  Text(0.8735005452562704, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.8778625954198473, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0]'),
#  Text(0.8844056706652127, 0.7045454545454546, 'X[4] <= -0.691\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2]'),
#  Text(0.8822246455834242, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.8865866957470011, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.8844056706652127, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.941793893129771, 0.7954545454545454, 'X[4] <= 0.465\ngini = 0.736\nsamples = 71\nvalue = [19, 27, 6, 6, 13]'),
#  Text(0.9182115594329335, 0.75, 'X[4] <= -0.691\ngini = 0.688\nsamples = 45\nvalue = [13, 20, 5, 1, 6]'),
#  Text(0.9007633587786259, 0.7045454545454546, 'X[6] <= 0.599\ngini = 0.759\nsamples = 19\nvalue = [3, 6, 5, 1, 4]'),
#  Text(0.8909487459105779, 0.6590909090909091, 'X[3] <= 1.096\ngini = 0.667\nsamples = 12\nvalue = [1, 6, 3, 1, 1]'),
#  Text(0.8887677208287895, 0.6136363636363636, 'X[3] <= -0.66\ngini = 0.741\nsamples = 9\nvalue = [1, 3, 3, 1, 1]'),
#  Text(0.8822246455834242, 0.5681818181818182, 'X[6] <= -0.044\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0, 0]'),
#  Text(0.8800436205016358, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.8844056706652127, 0.5227272727272727, 'X[0] <= 0.051\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.8822246455834242, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8865866957470011, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.8953107960741549, 0.5681818181818182, 'X[2] <= 0.349\ngini = 0.72\nsamples = 5\nvalue = [1, 0, 2, 1, 1]'),
#  Text(0.8931297709923665, 0.5227272727272727, 'X[4] <= -1.269\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 0, 1, 1]'),
#  Text(0.8909487459105779, 0.4772727272727273, 'X[1] <= 0.056\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0]'),
#  Text(0.8887677208287895, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.8931297709923665, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.8953107960741549, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.8974918211559433, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.8931297709923665, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.910577971646674, 0.6590909090909091, 'X[0] <= 0.051\ngini = 0.653\nsamples = 7\nvalue = [2, 0, 2, 0, 3]'),
#  Text(0.906215921483097, 0.6136363636363636, 'X[6] <= 1.243\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2]'),
#  Text(0.9040348964013086, 0.5681818181818182, 'X[1] <= -0.531\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2]'),
#  Text(0.9018538713195202, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.906215921483097, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.9083969465648855, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.9149400218102508, 0.6136363636363636, 'X[2] <= -0.307\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 0, 1]'),
#  Text(0.9127589967284624, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.9171210468920392, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.935659760087241, 0.7045454545454546, 'X[4] <= -0.113\ngini = 0.556\nsamples = 26\nvalue = [10, 14, 0, 0, 2]'),
#  Text(0.9280261723009815, 0.6590909090909091, 'X[2] <= -0.307\ngini = 0.54\nsamples = 10\nvalue = [6, 3, 0, 0, 1]'),
#  Text(0.9236641221374046, 0.6136363636363636, 'X[3] <= -0.075\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1]'),
#  Text(0.9214830970556162, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.925845147219193, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.9323882224645583, 0.6136363636363636, 'X[3] <= 0.511\ngini = 0.245\nsamples = 7\nvalue = [6, 1, 0, 0, 0]'),
#  Text(0.9302071973827699, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0, 0]'),
#  Text(0.9345692475463467, 0.5681818181818182, 'X[6] <= 0.599\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0]'),
#  Text(0.9323882224645583, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.9367502726281353, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9432933478735005, 0.6590909090909091, 'X[1] <= 1.426\ngini = 0.461\nsamples = 16\nvalue = [4, 11, 0, 0, 1]'),
#  Text(0.9411123227917121, 0.6136363636363636, 'X[2] <= -1.618\ngini = 0.391\nsamples = 15\nvalue = [4, 11, 0, 0, 0]'),
#  Text(0.9389312977099237, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9432933478735005, 0.5681818181818182, 'X[6] <= -0.044\ngini = 0.337\nsamples = 14\nvalue = [3, 11, 0, 0, 0]'),
#  Text(0.9411123227917121, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0]'),
#  Text(0.945474372955289, 0.5227272727272727, 'X[1] <= -0.923\ngini = 0.444\nsamples = 9\nvalue = [3, 6, 0, 0, 0]'),
#  Text(0.9432933478735005, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9476553980370774, 0.4772727272727273, 'X[3] <= -0.075\ngini = 0.375\nsamples = 8\nvalue = [2, 6, 0, 0, 0]'),
#  Text(0.945474372955289, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.9498364231188658, 0.4318181818181818, 'X[1] <= -0.531\ngini = 0.48\nsamples = 5\nvalue = [2, 3, 0, 0, 0]'),
#  Text(0.9476553980370774, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9520174482006543, 0.38636363636363635, 'X[2] <= -0.307\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0, 0, 0]'),
#  Text(0.9498364231188658, 0.3409090909090909, 'X[3] <= 0.511\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0]'),
#  Text(0.9476553980370774, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.9520174482006543, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9541984732824428, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.945474372955289, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.9653762268266085, 0.75, 'X[2] <= -1.618\ngini = 0.763\nsamples = 26\nvalue = [6, 7, 1, 5, 7]'),
#  Text(0.9520174482006543, 0.7045454545454546, 'X[3] <= 0.511\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0, 0, 0]'),
#  Text(0.9498364231188658, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.9541984732824428, 0.6590909090909091, 'X[6] <= 1.243\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0]'),
#  Text(0.9520174482006543, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.9563794983642312, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9787350054525628, 0.7045454545454546, 'X[6] <= 0.599\ngini = 0.753\nsamples = 21\nvalue = [3, 5, 1, 5, 7]'),
#  Text(0.9683751363140676, 0.6590909090909091, 'X[3] <= 0.511\ngini = 0.667\nsamples = 12\nvalue = [2, 2, 0, 2, 6]'),
#  Text(0.960741548527808, 0.6136363636363636, 'X[4] <= 1.043\ngini = 0.494\nsamples = 9\nvalue = [1, 2, 0, 0, 6]'),
#  Text(0.9563794983642312, 0.5681818181818182, 'X[0] <= 0.051\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 0, 5]'),
#  Text(0.9541984732824428, 0.5227272727272727, 'X[6] <= -0.044\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 2]'),
#  Text(0.9520174482006543, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.9563794983642312, 0.4772727272727273, 'X[3] <= -0.66\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1]'),
#  Text(0.9541984732824428, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.9585605234460196, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.9585605234460196, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.965103598691385, 0.5681818181818182, 'X[1] <= -0.14\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 0, 1]'),
#  Text(0.9629225736095965, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.9672846237731734, 0.5227272727272727, 'X[2] <= -0.307\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0]'),
#  Text(0.965103598691385, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.9694656488549618, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9760087241003271, 0.6136363636363636, 'X[4] <= 1.043\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0]'),
#  Text(0.9738276990185387, 0.5681818181818182, 'X[2] <= 0.677\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0]'),
#  Text(0.9716466739367503, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9760087241003271, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.9781897491821155, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.9890948745910578, 0.6590909090909091, 'X[3] <= -0.66\ngini = 0.741\nsamples = 9\nvalue = [1, 3, 1, 3, 1]'),
#  Text(0.9847328244274809, 0.6136363636363636, 'X[6] <= 1.243\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0]'),
#  Text(0.9825517993456925, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.9869138495092693, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.9934569247546347, 0.6136363636363636, 'X[3] <= 1.096\ngini = 0.56\nsamples = 5\nvalue = [1, 3, 0, 0, 1]'),
#  Text(0.9912758996728462, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.9956379498364231, 0.5681818181818182, 'X[4] <= 1.043\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1]'),
#  Text(0.9934569247546347, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.9978189749182116, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]')]

# %%
print("Accuracy: ",metrics.accuracy_score(Y_test, Predicted_class)*100)
print("Confusion Matrix: ")
print(metrics.confusion_matrix(Y_test, Predicted_class))
print("Classification Report: ")
print(metrics.classification_report(Y_test,Predicted_class))
# Out:
# Accuracy:  28.888888888888886
# Confusion Matrix:
# [[ 6  4  4  1  6]
#  [13 22 14 13 15]
#  [ 4  3  8  2  7]
#  [ 7  6  5 13  9]
#  [24 33 22 32 42]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   dependable       0.11      0.29      0.16        21
#  extraverted       0.32      0.29      0.30        77
#       lively       0.15      0.33      0.21        24
#  responsible       0.21      0.33      0.26        40
#      serious       0.53      0.27      0.36       153
#
#     accuracy                           0.29       315
#    macro avg       0.27      0.30      0.26       315
# weighted avg       0.38      0.29      0.31       315

# %% [markdown]
# # Support Vector Machines

# %%
clf = svm.SVC()
clf.fit(X,Y)
Predicted_class = clf.predict(X_test)
Predicted_class
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['dependable', 'responsible', 'lively', 'lively', 'serious',
#        'lively', 'extraverted', 'lively', 'serious', 'serious', 'serious',
#        'responsible', 'responsible', 'serious', 'dependable',
#        'dependable', 'lively', 'serious', 'serious', 'lively', 'serious',
#        'extraverted', 'serious', 'dependable', 'responsible', 'lively',
#        'serious', 'serious', 'extraverted', 'responsible', 'serious',
#        'serious', 'serious', 'responsible', 'serious', 'serious',
#        'extraverted', 'serious', 'serious', 'serious', 'responsible',
#        'serious', 'serious', 'dependable', 'serious', 'extraverted',
#        'dependable', 'serious', 'serious', 'extraverted', 'extraverted',
#        'lively', 'serious', 'serious', 'serious', 'lively', 'extraverted',
#        'serious', 'serious', 'serious', 'serious', 'serious',
#        'dependable', 'extraverted', 'extraverted', 'serious',
#        'extraverted', 'dependable', 'extraverted', 'serious', 'serious',
#        'extraverted', 'extraverted', 'serious', 'serious', 'serious',
#        'serious', 'serious', 'lively', 'serious', 'serious', 'serious',
#        'serious', 'extraverted', 'extraverted', 'lively', 'serious',
#        'serious', 'extraverted', 'lively', 'serious', 'lively', 'serious',
#        'extraverted', 'extraverted', 'lively', 'serious', 'extraverted',
#        'lively', 'lively', 'lively', 'extraverted', 'extraverted',
#        'lively', 'serious', 'dependable', 'extraverted', 'serious',
#        'serious', 'serious', 'serious', 'extraverted', 'serious',
#        'dependable', 'serious', 'extraverted', 'responsible', 'serious',
#        'serious', 'extraverted', 'lively', 'responsible', 'serious',
#        'extraverted', 'serious', 'serious', 'serious', 'serious',
#        'responsible', 'serious', 'extraverted', 'lively', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'serious',
#        'serious', 'serious', 'serious', 'dependable', 'serious',
#        'responsible', 'extraverted', 'lively', 'serious', 'lively',
#        'serious', 'serious', 'dependable', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'extraverted', 'extraverted', 'serious', 'serious',
#        'extraverted', 'serious', 'serious', 'dependable', 'serious',
#        'serious', 'serious', 'serious', 'dependable', 'serious',
#        'extraverted', 'responsible', 'serious', 'responsible', 'serious',
#        'serious', 'serious', 'extraverted', 'serious', 'serious',
#        'serious', 'responsible', 'dependable', 'lively', 'extraverted',
#        'dependable', 'serious', 'lively', 'extraverted', 'responsible',
#        'lively', 'serious', 'extraverted', 'lively', 'serious',
#        'responsible', 'lively', 'serious', 'serious', 'lively', 'lively',
#        'serious', 'serious', 'serious', 'serious', 'serious',
#        'extraverted', 'extraverted', 'serious', 'extraverted', 'serious',
#        'serious', 'serious', 'serious', 'dependable', 'serious',
#        'dependable', 'serious', 'extraverted', 'dependable',
#        'extraverted', 'serious', 'dependable', 'dependable', 'serious',
#        'serious', 'extraverted', 'serious', 'extraverted', 'extraverted',
#        'serious', 'serious', 'extraverted', 'serious', 'serious',
#        'extraverted', 'extraverted', 'serious', 'lively', 'extraverted',
#        'extraverted', 'dependable', 'extraverted', 'dependable',
#        'dependable', 'serious', 'serious', 'dependable', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'lively', 'dependable',
#        'lively', 'extraverted', 'responsible', 'extraverted',
#        'dependable', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'dependable', 'extraverted', 'extraverted',
#        'extraverted', 'responsible', 'extraverted', 'dependable',
#        'dependable', 'extraverted', 'dependable', 'serious',
#        'extraverted', 'serious', 'serious', 'extraverted', 'dependable',
#        'serious', 'serious', 'extraverted', 'lively', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'lively', 'responsible',
#        'extraverted', 'extraverted', 'extraverted', 'serious', 'lively',
#        'extraverted', 'serious', 'lively', 'serious', 'serious',
#        'serious', 'lively', 'extraverted', 'extraverted', 'serious',
#        'serious'], dtype=object)

# %%
print("Accuracy: ",metrics.accuracy_score(Y_test, Predicted_class)*100)
print("Confusion Matrix: ")
print(metrics.confusion_matrix(Y_test, Predicted_class))
print("Classification Report: ")
print(metrics.classification_report(Y_test,Predicted_class))
# Out:
# Accuracy:  37.46031746031746
# Confusion Matrix:
# [[ 5  5  2  0  9]
#  [10 24  8  3 32]
#  [ 2  1  5  5 11]
#  [ 4  4  2  7 23]
#  [11 40 20  5 77]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   dependable       0.16      0.24      0.19        21
#  extraverted       0.32      0.31      0.32        77
#       lively       0.14      0.21      0.16        24
#  responsible       0.35      0.17      0.23        40
#      serious       0.51      0.50      0.50       153
#
#     accuracy                           0.37       315
#    macro avg       0.29      0.29      0.28       315
# weighted avg       0.39      0.37      0.38       315

# %% [markdown]
# # Using Linear SVC

# %%
clf = svm.LinearSVC()
clf.fit(X,Y)
Predicted_class = clf.predict(X_test)
Predicted_class
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# array(['extraverted', 'responsible', 'serious', 'serious', 'responsible',
#        'serious', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'responsible', 'extraverted', 'serious', 'lively', 'extraverted',
#        'serious', 'serious', 'serious', 'extraverted', 'serious',
#        'extraverted', 'serious', 'extraverted', 'serious', 'serious',
#        'extraverted', 'extraverted', 'serious', 'responsible', 'serious',
#        'lively', 'extraverted', 'lively', 'serious', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'responsible', 'responsible',
#        'serious', 'lively', 'serious', 'serious', 'responsible',
#        'serious', 'serious', 'extraverted', 'serious', 'serious',
#        'serious', 'lively', 'extraverted', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'responsible', 'serious',
#        'extraverted', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'serious', 'responsible', 'extraverted', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'extraverted',
#        'extraverted', 'serious', 'lively', 'serious', 'serious',
#        'serious', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'extraverted', 'extraverted', 'extraverted',
#        'extraverted', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'serious', 'lively', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'serious',
#        'extraverted', 'lively', 'lively', 'serious', 'serious', 'lively',
#        'serious', 'serious', 'serious', 'responsible', 'serious',
#        'serious', 'dependable', 'serious', 'serious', 'dependable',
#        'serious', 'responsible', 'extraverted', 'serious', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'serious',
#        'extraverted', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'lively', 'extraverted', 'extraverted', 'serious',
#        'responsible', 'extraverted', 'serious', 'extraverted',
#        'responsible', 'extraverted', 'extraverted', 'serious', 'serious',
#        'responsible', 'serious', 'extraverted', 'extraverted',
#        'extraverted', 'serious', 'serious', 'serious', 'responsible',
#        'responsible', 'serious', 'serious', 'lively', 'serious',
#        'serious', 'serious', 'lively', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'extraverted', 'serious',
#        'lively', 'serious', 'extraverted', 'serious', 'extraverted',
#        'responsible', 'serious', 'serious', 'extraverted', 'lively',
#        'serious', 'serious', 'serious', 'serious', 'extraverted',
#        'extraverted', 'serious', 'extraverted', 'extraverted',
#        'extraverted', 'extraverted', 'lively', 'extraverted',
#        'extraverted', 'dependable', 'serious', 'serious', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'serious', 'extraverted',
#        'serious', 'extraverted', 'extraverted', 'serious', 'extraverted',
#        'serious', 'serious', 'extraverted', 'extraverted', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'responsible', 'extraverted', 'serious',
#        'extraverted', 'serious', 'extraverted', 'serious', 'responsible',
#        'responsible', 'extraverted', 'lively', 'serious', 'responsible',
#        'responsible', 'lively', 'serious', 'serious', 'extraverted',
#        'serious', 'serious', 'serious', 'serious', 'extraverted',
#        'serious', 'extraverted', 'serious', 'responsible', 'responsible',
#        'extraverted', 'extraverted', 'serious', 'serious', 'responsible',
#        'extraverted', 'serious', 'extraverted', 'lively', 'extraverted',
#        'serious', 'extraverted', 'extraverted', 'extraverted',
#        'extraverted', 'extraverted', 'extraverted', 'serious',
#        'extraverted', 'extraverted', 'extraverted', 'extraverted',
#        'extraverted', 'extraverted', 'serious', 'serious', 'serious',
#        'serious', 'serious', 'serious', 'serious', 'serious', 'serious',
#        'serious', 'extraverted', 'serious', 'serious', 'extraverted',
#        'extraverted'], dtype=object)

# %%
print("Accuracy: ",metrics.accuracy_score(Y_test, Predicted_class)*100)
print("Confusion Matrix: ")
print(metrics.confusion_matrix(Y_test, Predicted_class))
print("Classification Report: ")
print(metrics.classification_report(Y_test,Predicted_class))
# Out:
# Accuracy:  82.85714285714286
# Confusion Matrix:
# [[  3   6   0   0  12]
#  [  0  71   1   0   5]
#  [  0   3  18   1   2]
#  [  0   7   0  25   8]
#  [  0   8   0   1 144]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   dependable       1.00      0.14      0.25        21
#  extraverted       0.75      0.92      0.83        77
#       lively       0.95      0.75      0.84        24
#  responsible       0.93      0.62      0.75        40
#      serious       0.84      0.94      0.89       153
#
#     accuracy                           0.83       315
#    macro avg       0.89      0.68      0.71       315
# weighted avg       0.85      0.83      0.81       315

# %% [markdown]
# # Random Forest

# %%
df_test['Personality'] = label.fit_transform(df_test['Personality'])
df_train['Personality'] = label.fit_transform(df_train['Personality'])
X = np.array(df_train[input_columns])
Y = np.array(df_train[output_columns])
X_test = np.array(df_test[input_columns])
Y_test = np.array(df_test[output_columns])
rf = RandomForestRegressor(n_estimators = 10000, random_state = 50, criterion ="poisson")
rf.fit(X,Y)
Predicted_class = rf.predict(X_test)
final = []
for i in Predicted_class:
    final.append(math.ceil(i))
Predicted_class = np.array(final)
Predicted_class
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2072\1624550960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Personality'] = label.fit_transform(df_test['Personality'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2072\1624550960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Personality'] = label.fit_transform(df_train['Personality'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2072\1624550960.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X,Y)
# array([3, 3, 4, 3, 4, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 3, 3, 4, 3, 4, 3,
#        2, 3, 2, 2, 4, 4, 3, 4, 3, 3, 3, 2, 4, 3, 3, 3, 4, 3, 3, 3, 3, 4,
#        3, 3, 3, 3, 3, 2, 3, 2, 4, 3, 2, 3, 4, 3, 3, 4, 3, 2, 3, 3, 3, 3,
#        3, 3, 3, 2, 3, 3, 3, 3, 4, 2, 2, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 2, 2, 3, 3, 3, 2, 3, 2, 3, 3, 4, 3, 3, 2, 3, 3, 2, 4, 3,
#        4, 2, 3, 3, 2, 2, 3, 4, 3, 3, 3, 3, 4, 3, 4, 2, 3, 3, 3, 2, 3, 2,
#        4, 3, 3, 2, 3, 3, 3, 2, 3, 3, 4, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 1,
#        3, 3, 4, 3, 3, 2, 2, 2, 4, 3, 3, 3, 3, 4, 3, 4, 3, 3, 4, 3, 2, 3,
#        4, 3, 3, 3, 3, 2, 3, 3, 4, 3, 3, 2, 3, 3, 3, 2, 3, 4, 3, 2, 3, 2,
#        3, 4, 3, 4, 3, 3, 2, 3, 3, 3, 3, 4, 2, 3, 3, 4, 3, 3, 3, 3, 3, 3,
#        3, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 4, 3, 3, 2, 3, 3,
#        3, 4, 2, 2, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2,
#        2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 2, 3, 3, 2, 4, 3, 3, 2, 4, 3,
#        2, 2, 2, 4, 3, 3, 3, 2, 3, 4, 4, 2, 4, 2, 3, 3, 3, 3, 2, 2, 3, 3,
#        2, 4, 3, 4, 3, 3, 4])

# %%
df_test
# Out:
#        Gender       Age  openness  neuroticism  conscientiousness  \
# 0   -0.946744  0.055818  1.332469     2.559776           2.488986
# 1    1.048042 -1.118659  0.021130    -0.367643           0.176171
# 2   -0.946744  2.013280  0.021130     0.217841           1.332579
# 3   -0.946744 -0.727166  0.676799    -1.538610           1.332579
# 4   -0.946744 -0.335674 -1.945878    -0.367643           1.332579
# ..        ...       ...       ...          ...                ...
# 310 -0.946744 -0.335674  0.676799     0.217841           0.754375
# 311  1.048042 -0.727166 -1.945878     0.217841           1.910783
# 312  1.048042 -0.727166  1.332469     0.217841           0.754375
# 313  1.048042  1.230295  0.676799     1.388809           0.176171
# 314 -0.946744 -0.727166  0.021130     1.388809          -0.980236
#
#      agreeableness  extraversion  Personality
# 0         0.100728      0.277742            0
# 1        -1.708840     -0.365714            4
# 2        -1.708840     -0.365714            4
# 3        -0.502461      1.564654            4
# 4        -2.312029     -1.009171            3
# ..             ...           ...          ...
# 310      -0.502461     -1.009171            1
# 311      -1.105651      1.564654            0
# 312      -1.708840      1.564654            4
# 313      -0.502461     -1.009171            1
# 314       0.100728      0.921198            1
#
# [315 rows x 8 columns]

# %%
print("Accuracy: ",metrics.accuracy_score(Y_test, Predicted_class)*100)
print("Confusion Matrix: ")
print(metrics.confusion_matrix(Y_test, Predicted_class))
print("Classification Report: ")
print(metrics.classification_report(Y_test,Predicted_class))
# Out:
# Accuracy:  14.920634920634921
# Confusion Matrix:
# [[  0   0   4  12   5]
#  [  0   1  24  38  14]
#  [  0   0   1  19   4]
#  [  0   0   4  28   8]
#  [  0   0  30 106  17]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        21
#            1       1.00      0.01      0.03        77
#            2       0.02      0.04      0.02        24
#            3       0.14      0.70      0.23        40
#            4       0.35      0.11      0.17       153
#
#     accuracy                           0.15       315
#    macro avg       0.30      0.17      0.09       315
# weighted avg       0.44      0.15      0.12       315
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
